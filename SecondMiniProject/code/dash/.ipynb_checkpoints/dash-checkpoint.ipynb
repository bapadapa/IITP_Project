# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
from scipy import stats

import plotly.express as px
import dash
import dash_html_components as html
import dash_core_components as dcc
import dash_bootstrap_components as dbc
from dash.dependencies import Input, Output, State
import sys
sys.path.append("../generator")

# 생성한 모듈 경로
import generate_mod
# 그 외의 모듈들
import tensorflow as tf

# %%
vpredict=dbc.Card([
    dcc.RadioItems(
                id='radio_button_paid_search',
            options=[
                {'label': '로맨스  ', 'value': 'model_romance'},
                {'label': '추리   ', 'value': 'model_reasoning'},
                {'label': '무협   ', 'value': 'model_matial_arts'}
            ],
            labelStyle={'display': 'inline-block'},
            style={'color':'gray',
                'font-weight': 'bold',
                  'border-radius': '2em',
                   'fontSize':40
                  }
            ),
    dbc.CardBody(style={'backgroundColor': 'white',
                    'background-image': "url('/assets/책그림.png')",
                   'background-repeat':'no-repeat',
                   'background-size': '100% 100%',
                        'width':'100%','height':'300px',
                      'textAlign': 'center'},
                        children= [
            
            dcc.Input(
                id='keyword',
                type='text',
                style={'color':'gray',
                       'textAlign': 'center',
                       'fontSize': 40,
                       'backgroundColor': 'white',
                        'width':'200px','height':'50px',
                       'background-color': 'white'
                    
                       }
            ),
            html.Button('만들기', id='submit-val', n_clicks=0, style = {'textAlign': 'center',
                                                               'size': 30,
                                                               'fontSize':20,
                                                               'background-color': 'gray',
                                                               'color': '#ffffff',
                                                               'font-weight': 'bold',
                                                               'border': '0.2rem solid',
                                                               'border-radius': '60px',
                                                               'border-color':'#E2E2E2',
                                                               'padding': '1rem 1.5rem',
                                                               'cursor': 'pointer',
                                                               'transition': 'all 0.15s'})
                
                                                                                            
    ])
])

pre = dbc.Card([
                   html.Div( id = 'predict',
                            style = {'weight':300,
                                    'textAlign': 'center', 
                                    'fontSize': 10,
                                    'color':'black',
                                    'border-style': 'solid;white'
                                }
                            )
                          
              ])

# %%
app = dash.Dash(__name__,external_stylesheets=[dbc.themes.SIMPLEX])
search_result = dbc.Card(style={'border-style': 'solid;white'
                              },
                children=[
    dbc.CardBody(style={'textAlign':'center',
                       'width':'100%','height':'100%'},
                 children=[
        dbc.Row(
                dbc.Col(style={
                                             'align': 'center', 
                                             'width':'100%','height':'400px'
                    },
                        children=[

                    html.H2(vpredict, style={
                                             'align': 'center', 
                                             'width':'100%','height':'400px'
                    }),
                               
                        ])
                ),
        dbc.Row([
                dbc.Col(style={'textAlign': 'center',
                    'backgroundColor': 'white',
                    'background-image': "url('/assets/노노.png')",
                   'background-repeat':'no-repeat',
                   'background-size': '100% 800px'},
                     
              children=[
                   html.H1('나만의 소설', style={ 'weight': '300px',
                                              'textAlign': 'center',
                                              'color':'black',
                                           'font-weight': 'bold'}),
              
                   html.Div(id='predict',
                             style={'weight': 500,
                                    'textAlign': 'center',
                                    'fontSize': 20,
                                    'width':'100%','height':'100%',
                                    'color':'black'
                                    })
                    
                ])
            ])
        
    ])
])    

app.layout = html.Div([
    
    html.Div(
        style={'backgroundColor': 'white',
              'border-style': 'solid;white'},
         children=
        [
           html.Img(src=app.get_asset_url('./배.jpg'),
            style={'width':'100%','height':'100%'}),
           search_result,
            html.Img(src=app.get_asset_url('./기쁨.png'), style={'width':'100%','height':'100px'})
          ]
    )
])

# %%
@app.callback(
    Output('predict','children'),
    Input('submit-val','n_clicks'),
    State('keyword', 'value'),
    State('radio_button_paid_search','value')
)

def update_predict(n_clicks,keyword,novel_type):
    idx = 0
    if novel_type == 'model_romance':
        model_name = '로맨스 소설 : '
        idx = 0
    elif novel_type == 'model_reasoning':
        model_name = '추리 소설 : '
        idx = 1
    else:
        model_name = '무협 소설 : '
        idx =2
    
    result = 'ㄹㅇ나ㅓ호마널오후ㅏㅓㄹ미ㄹㅇ나ㅓ호마널오후ㅏㅓㄹ미ㄹㅇ나ㅓ호마널오후ㅏㅓㄹ미ㄹㅇ나ㅓ호마널오후ㅏㅓㄹ미ㄹㅇ나ㅓ호마널오후ㅏㅓㄹ미ㄹㅇ나ㅓ호마널오후ㅏㅓㄹ미ㄹㅇ나ㅓ호마널오후ㅏㅓㄹ미ㄹㅇ나ㅓ호마널오후ㅏㅓㄹ미ㄹㅇ나ㅓ호마널오후ㅏㅓㄹ미ㄹㅇ나ㅓ호마널오후ㅏㅓㄹ미ㄹㅇ나ㅓ호마널오후ㅏㅓㄹ미'

    
    return html.Div([
           html.H4(model_name+ str(result)),n_clicks
        ])

# %%
generate_mod.generate_text(
                    model_index = idx, 
                    start_string = f'{keyword} ',
                    num_generate = 1000,
                    temperature = 0.7
                    )

# %%
app.run_server(port='1111')
# Out:
# Dash is running on http://127.0.0.1:1111/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:1111/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Aug/2021 17:46:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2021 17:46:05] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2021 17:46:05] "GET /_dash-dependencies HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "../generator\generate_mod.py", line 35, in read_text
#     with open(file_path,'rb') as common:
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/novels/martialArts.txt'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-5e2fce7a8012>", line 20, in update_predict
#     result = generate_mod.generate_text(
#   File "../generator\generate_mod.py", line 180, in generate_text
#     text = read_text(config['novel_Path']+config['genres'][model_index]+'.txt')
#   File "../generator\generate_mod.py", line 38, in read_text
#     with open(file_path,'rb') as common:
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/novels/martialArts.txt'
# 127.0.0.1 - - [03/Aug/2021 17:46:05] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "../generator\generate_mod.py", line 35, in read_text
#     with open(file_path,'rb') as common:
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/novels/martialArts.txt'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-5e2fce7a8012>", line 20, in update_predict
#     result = generate_mod.generate_text(
#   File "../generator\generate_mod.py", line 180, in generate_text
#     text = read_text(config['novel_Path']+config['genres'][model_index]+'.txt')
#   File "../generator\generate_mod.py", line 38, in read_text
#     with open(file_path,'rb') as common:
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/novels/martialArts.txt'
# 127.0.0.1 - - [03/Aug/2021 17:46:14] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "../generator\generate_mod.py", line 35, in read_text
#     with open(file_path,'rb') as common:
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/novels/martialArts.txt'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-5e2fce7a8012>", line 20, in update_predict
#     result = generate_mod.generate_text(
#   File "../generator\generate_mod.py", line 180, in generate_text
#     text = read_text(config['novel_Path']+config['genres'][model_index]+'.txt')
#   File "../generator\generate_mod.py", line 38, in read_text
#     with open(file_path,'rb') as common:
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/novels/martialArts.txt'
# 127.0.0.1 - - [03/Aug/2021 17:46:14] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "../generator\generate_mod.py", line 35, in read_text
#     with open(file_path,'rb') as common:
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/novels/martialArts.txt'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-5e2fce7a8012>", line 20, in update_predict
#     result = generate_mod.generate_text(
#   File "../generator\generate_mod.py", line 180, in generate_text
#     text = read_text(config['novel_Path']+config['genres'][model_index]+'.txt')
#   File "../generator\generate_mod.py", line 38, in read_text
#     with open(file_path,'rb') as common:
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/novels/martialArts.txt'
# 127.0.0.1 - - [03/Aug/2021 17:46:16] "POST /_dash-update-component HTTP/1.1" 500 -
