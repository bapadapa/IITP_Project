# %%
# 생성한 모듈 경로
import generate_mod
# 그 외의 모듈들
import tensorflow as tf

#파일 가져오기
# Json 파일 및 소설 가져오기 읽기
config = generate_mod.read_json()
text = generate_mod.read_all_text(config,config['genres'][1])

# 인덱싱 사전 생성 및 모든 텍스트 맵핑시킴
vocab, char2idx, idx2char , text_as_int  = generate_mod.indexing(text)

# training Sample/Target 생성
# numpy -> tensor 형변환이라고 생각하는게 편함
char_dataset = tf.data.Dataset.from_tensor_slices(text_as_int)

# 청크파일 만들기 (즉 훈련 셈플등을 구하기)
sequences = char_dataset.batch(config['seq_length']+1 , drop_remainder = True)
dataset = sequences.map(generate_mod.split_input_target)

# 읽어온 텍스트 길이로 버퍼 크기 선정
Buffer_size = len(text_as_int) * 2

# BUFFER_SIZE개로 이루어진 버퍼로 임의의 샘플을 뽑은 후 BATCH_SIZE로 분할한다.
dataset = dataset.shuffle(Buffer_size).batch(config['batch_size'], drop_remainder= True)

# 모델생성
model = generate_mod.model_learning(
    config = config,
    vocab = vocab,
    dataset= dataset,
    genre_Index = 1
    )
# Out:
# Epoch 1/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 3.2294
# Epoch 2/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 2.6474
# Epoch 3/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 2.4968
# Epoch 4/150
# 1266/1266 [==============================] - 250s 197ms/step - loss: 2.4076
# Epoch 5/150
# 1266/1266 [==============================] - 251s 198ms/step - loss: 2.3459
# Epoch 6/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 2.2986
# Epoch 7/150
# 1266/1266 [==============================] - 246s 195ms/step - loss: 2.2605
# Epoch 8/150
# 1266/1266 [==============================] - 245s 194ms/step - loss: 2.2290
# Epoch 9/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 2.2020
# Epoch 10/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 2.1783
# Epoch 11/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 2.1570
# Epoch 12/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 2.1376
# Epoch 13/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 2.1198
# Epoch 14/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 2.1034
# Epoch 15/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 2.0882
# Epoch 16/150
# 1266/1266 [==============================] - 244s 193ms/step - loss: 2.0739
# Epoch 17/150
# 1266/1266 [==============================] - 245s 193ms/step - loss: 2.0605
# Epoch 18/150
# 1266/1266 [==============================] - 244s 192ms/step - loss: 2.0479
# Epoch 19/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 2.0361
# Epoch 20/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 2.0247
# Epoch 21/150
# 1266/1266 [==============================] - 246s 195ms/step - loss: 2.0138
# Epoch 22/150
# 1266/1266 [==============================] - 244s 193ms/step - loss: 2.0039
# Epoch 23/150
# 1266/1266 [==============================] - 244s 193ms/step - loss: 1.9945
# Epoch 24/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 1.9849
# Epoch 25/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.9761
# Epoch 26/150
# 1266/1266 [==============================] - 245s 193ms/step - loss: 1.9679
# Epoch 27/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.9599
# Epoch 28/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.9523
# Epoch 29/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.9450
# Epoch 30/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.9383
# Epoch 31/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.9318
# Epoch 32/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.9255
# Epoch 33/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 1.9193
# Epoch 34/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 1.9138
# Epoch 35/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 1.9086
# Epoch 36/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 1.9034
# Epoch 37/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8985
# Epoch 38/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8937
# Epoch 39/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8890
# Epoch 40/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 1.8854
# Epoch 41/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8814
# Epoch 42/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8775
# Epoch 43/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8737
# Epoch 44/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8702
# Epoch 45/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 1.8673
# Epoch 46/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8639
# Epoch 47/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8614
# Epoch 48/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8581
# Epoch 49/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8555
# Epoch 50/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8532
# Epoch 51/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 1.8510
# Epoch 52/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 1.8488
# Epoch 53/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8466
# Epoch 54/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8444
# Epoch 55/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8421
# Epoch 56/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8406
# Epoch 57/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8389
# Epoch 58/150
# 1266/1266 [==============================] - 244s 193ms/step - loss: 1.8372
# Epoch 59/150
# 1266/1266 [==============================] - 245s 193ms/step - loss: 1.8354
# Epoch 60/150
# 1266/1266 [==============================] - 243s 192ms/step - loss: 1.8341
# Epoch 61/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8326
# Epoch 62/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8314
# Epoch 63/150
# 1266/1266 [==============================] - 245s 193ms/step - loss: 1.8296
# Epoch 64/150
# 1266/1266 [==============================] - 244s 193ms/step - loss: 1.8288
# Epoch 65/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8278
# Epoch 66/150
# 1266/1266 [==============================] - 244s 193ms/step - loss: 1.8264
# Epoch 67/150
# 1266/1266 [==============================] - 244s 193ms/step - loss: 1.8254
# Epoch 68/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8245
# Epoch 69/150
# 1266/1266 [==============================] - 242s 191ms/step - loss: 1.8234
# Epoch 70/150
# 1266/1266 [==============================] - 245s 194ms/step - loss: 1.8227
# Epoch 71/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8216
# Epoch 72/150
# 1266/1266 [==============================] - 246s 195ms/step - loss: 1.8212
# Epoch 73/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8200
# Epoch 74/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8192
# Epoch 75/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8187
# Epoch 76/150
# 1266/1266 [==============================] - 246s 195ms/step - loss: 1.8181
# Epoch 77/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8169
# Epoch 78/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8170
# Epoch 79/150
# 1266/1266 [==============================] - 246s 195ms/step - loss: 1.8159
# Epoch 80/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8155
# Epoch 81/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8143
# Epoch 82/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8143
# Epoch 83/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8138
# Epoch 84/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8133
# Epoch 85/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8126
# Epoch 86/150
# 1266/1266 [==============================] - 248s 196ms/step - loss: 1.8122
# Epoch 87/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8116
# Epoch 88/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8114
# Epoch 89/150
# 1266/1266 [==============================] - 246s 195ms/step - loss: 1.8113
# Epoch 90/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8108
# Epoch 91/150
# 1266/1266 [==============================] - 245s 194ms/step - loss: 1.8105
# Epoch 92/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8101
# Epoch 93/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8096
# Epoch 94/150
# 1266/1266 [==============================] - 246s 195ms/step - loss: 1.8090
# Epoch 95/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8092
# Epoch 96/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8088
# Epoch 97/150
# 1266/1266 [==============================] - 245s 194ms/step - loss: 1.8084
# Epoch 98/150
# 1266/1266 [==============================] - 248s 196ms/step - loss: 1.8081
# Epoch 99/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8077
# Epoch 100/150
# 1266/1266 [==============================] - 249s 197ms/step - loss: 1.8077
# Epoch 101/150
# 1266/1266 [==============================] - 248s 196ms/step - loss: 1.8075
# Epoch 102/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8069
# Epoch 103/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8067
# Epoch 104/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8070
# Epoch 105/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8065
# Epoch 106/150
# 1266/1266 [==============================] - 245s 194ms/step - loss: 1.8064
# Epoch 107/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8060
# Epoch 108/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8057
# Epoch 109/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8056
# Epoch 110/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8053
# Epoch 111/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8050
# Epoch 112/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8049
# Epoch 113/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8049
# Epoch 114/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8054
# Epoch 115/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8044
# Epoch 116/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8040
# Epoch 117/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8041
# Epoch 118/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8042
# Epoch 119/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8043
# Epoch 120/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8040
# Epoch 121/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8041
# Epoch 122/150
# 1266/1266 [==============================] - 246s 195ms/step - loss: 1.8059
# Epoch 123/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8044
# Epoch 124/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8034
# Epoch 125/150
# 1266/1266 [==============================] - 245s 194ms/step - loss: 1.8038
# Epoch 126/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8037
# Epoch 127/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8037
# Epoch 128/150
# 1266/1266 [==============================] - 246s 195ms/step - loss: 1.8035
# Epoch 129/150
# 1266/1266 [==============================] - 245s 194ms/step - loss: 1.8030
# Epoch 130/150
# 1266/1266 [==============================] - 245s 193ms/step - loss: 1.8034
# Epoch 131/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8032
# Epoch 132/150
# 1266/1266 [==============================] - 248s 196ms/step - loss: 1.8033
# Epoch 133/150
# 1266/1266 [==============================] - 246s 195ms/step - loss: 1.8030
# Epoch 134/150
# 1266/1266 [==============================] - 245s 193ms/step - loss: 1.8031
# Epoch 135/150
# 1266/1266 [==============================] - 245s 193ms/step - loss: 1.8027
# Epoch 136/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8033
# Epoch 137/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8027
# Epoch 138/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8029
# Epoch 139/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8030
# Epoch 140/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8025
# Epoch 141/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8024
# Epoch 142/150
# 1266/1266 [==============================] - 245s 194ms/step - loss: 1.8032
# Epoch 143/150
# 1266/1266 [==============================] - 246s 195ms/step - loss: 1.8025
# Epoch 144/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8028
# Epoch 145/150
# 1266/1266 [==============================] - 246s 194ms/step - loss: 1.8020
# Epoch 146/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8027
# Epoch 147/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8024
# Epoch 148/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8023
# Epoch 149/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8024
# Epoch 150/150
# 1266/1266 [==============================] - 247s 195ms/step - loss: 1.8031

# %%
# 생성한 모듈 경로
import generate_mod
# 그 외의 모듈들
import tensorflow as tf

text = generate_mod.generate_text(
    model_index = 2, 
    start_string = '마교 ',
    num_generate = 1000,
    temperature = 0.6
    )
text
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# '마교 줄지어 부적 하나 만들어 버렸다.\r\r\n이건 천마군 적이라고 볼 수 있는 권리는 혈마 진우곤이었다.\r\r\n그들은 잠시 그의 나무를 다시 내리쳤다.\r\r\n휙 휙\r\r\n머리를 잃어버리는 검신을 훑다가 검을 휘둘렀다.\r\r\n쐐애액!\r\r\n순식간에 연호의 검이 위주의 손에 닿으려고 하는 이들을 향해 고개를 돌렸다.\r\r\n그 순간 낭왕이 그 광경을 보고 있는 것을 본 연호는 눈을 좁혀 그를 불렀다.\r\r\n아니 네가 믿고 있는 게 이상하네.\r\r\n남궁천이 굳은 표정으로 말했다.\r\r\n좋습니다. 마음 같아서는 정상에 올라 수많은 유지장님 지역을 도와주실 수도 있겠어요.\r\r\n그렇게 말하며 나는 그들을 따라 걸음을 옮겼다. 그러자 여인이 큰 소리를 내며 날아오고 있었다.\r\r\n그리고 그곳에서 이씨의 도법 같은 모습을 보고 어느새 분위기가 무를 깼다.\r 어디 가냐고 내가 너무 심했던 거였어. 어쩌면 이러쿵저러쿵 하마터면 죽기 딱히 그리 버텼다.\r\r\n하지만 그녀는 그런 말을 하는 것이 아니라 그 자신을 기다리고 있던 대희가 눈물을 흘리며 고개를 끄덕였다.\r\r\n저 정도면 아무리 자존심이 상대가 아니라는 생각을 하며 자리를 벗어났다.\r\r\n당신이 뭐라고 하셨죠? 그 사람이 아무리 날카로운 고통을 겪었을 때 아는 것이 많았지만 말이다.\r\r\n선우는 부하들을 향해 가볍게 고개를 떨구었다.\r\r\n그래 여기서 이야기를 하는 것이 좋겠군.\r\r\n그 모습을 보던 총관이 고개를 절레절레 흔들었다.\r\r\n그럼 그렇지요.\r\r\n그가 무슨 말인지 아는 것인가?\r\r\n그래. 아무리 죽어가고 있어도 검이 반듯이 잡혀가고 있지만 그 후반 정도 무너진 것이 아니겠소?\r\r\n그저 나약함이 깊은 탓에 오작은 밖으로 나갈 수 없다는 듯 바로 눈치를 보며 말했다.\r\r\n그럼 어떻게 합니까?\r\r\n이제 와서 나가 대가 나와 있었다.\r\r\n사자귀 유다령이 검 날을 세차게 휘저었다.\r\r\n진청궁이 대답했다.\r\r\n다음에 대신 모욕한 건데 왜 해 안 들어가 있어야 하나?\r\r\n지휘관이 고개를 끄덕였다.\r\r\n네 놈이 오늘 싸움을 멈추고 나서야 일류로 갓 정신이 나'
